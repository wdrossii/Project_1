# %%
import numpy as np
import pandas as pd
import scipy.stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("InputData/MHRemoteData.csv")
df.head()
# Out:
#   Employee_ID  Age      Gender           Job_Role    Industry  \
# 0     EMP0001   32  Non-binary                 HR  Healthcare
# 1     EMP0002   40      Female     Data Scientist          IT
# 2     EMP0003   59  Non-binary  Software Engineer   Education
# 3     EMP0004   27        Male  Software Engineer     Finance
# 4     EMP0005   49        Male              Sales  Consulting
#
#    Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                   13        Hybrid                     47
# 1                    3        Remote                     52
# 2                   22        Hybrid                     46
# 3                   20        Onsite                     32
# 4                   32        Onsite                     35
#
#    Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                           7                         2       Medium
# 1                           4                         1       Medium
# ...

# %%
df['Stress_Level'] = df['Stress_Level'].replace({"Low": 1, "Medium": 5, "High": 10}, inplace=True)
# Out:
# C:\Users\rossd\AppData\Local\Temp\ipykernel_5024\2476072740.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Stress_Level'] = df['Stress_Level'].replace({"Low": 1, "Medium": 5, "High": 10}, inplace=True)
# ...

# %%
df['Physical_Activity'] = df['Physical_Activity'].replace({"Weekly": 1, "Daily": 7, "NaN": 0, "None": 0}, inplace=True)
# Out:
# C:\Users\rossd\AppData\Local\Temp\ipykernel_5024\697870833.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Physical_Activity'] = df['Physical_Activity'].replace({"Weekly": 1, "Daily": 7, "NaN": 0, "None": 0}, inplace=True)
# ...

# %%
MHRemoteReduced = df[["Employee_ID","Gender", "Age", "Job_Role", "Industry", "Years_of_Experience", "Work_Location", 
                               "Hours_Worked_Per_Week","Work_Life_Balance_Rating","Stress_Level", "Mental_Health_Condition", 
                               "Satisfaction_with_Remote_Work","Physical_Activity","Sleep_Quality","Region"]]

# %%
MHRemoteReduced.head()
# Out:
#   Employee_ID      Gender  Age           Job_Role    Industry  \
# 0     EMP0001  Non-binary   32                 HR  Healthcare
# 1     EMP0002      Female   40     Data Scientist          IT
# 2     EMP0003  Non-binary   59  Software Engineer   Education
# 3     EMP0004        Male   27  Software Engineer     Finance
# 4     EMP0005        Male   49              Sales  Consulting
#
#    Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                   13        Hybrid                     47
# 1                    3        Remote                     52
# 2                   22        Hybrid                     46
# 3                   20        Onsite                     32
# 4                   32        Onsite                     35
#
#    Work_Life_Balance_Rating Stress_Level Mental_Health_Condition  \
# 0                         2         None              Depression
# 1                         1         None                 Anxiety
# ...

# %%
MHRemoteReduced.count()
# Out:
# Employee_ID                      5000
# Gender                           5000
# Age                              5000
# Job_Role                         5000
# Industry                         5000
# Years_of_Experience              5000
# Work_Location                    5000
# Hours_Worked_Per_Week            5000
# Work_Life_Balance_Rating         5000
# Stress_Level                        0
# Mental_Health_Condition          3804
# Satisfaction_with_Remote_Work    5000
# Physical_Activity                   0
# Sleep_Quality                    5000
# Region                           5000
# dtype: int64

# %%
print(MHRemoteReduced.groupby(['Region']))

# %%
#pseudocode_DR:  group by region, then by work location, counting the employee ID for number of instances
#pseudocode_DR:  Chart bar graph with each bar representing the work locations, grouped by region, y-axis is instances, with a high of 350

# %%
#pseudocode_DR:  work location counting the employee ID for number of instances, then average social isolation rating
#pseudocode_DR:  Chart bar graph with each work location showing two bars, one for number of instances, and one showing the average social isolation rating

# %%
#pseudocode_DR: group by mental health condition, then by work loaction counting employee id for instances of each
#pseudocode_DR: see pivot table on guide spreadsheet for guidance.
