# %%
#Import modules.
import pandas as pd
import numpy as np
import random
import scipy.stats
import matplotlib.pyplot as plt

# %%
#Read file into dataframe.
df = pd.read_csv("C:/Users/melit/OneDrive/Data Analytics/Modules/Module 7 - Project 1/Project 1/Impact_of_Remote_Work_on_Mental_Health.csv")

#Print out first 5 rows.
df.head()
# Out:
#   Employee_ID  Age      Gender           Job_Role    Industry  \
# 0     EMP0001   32  Non-binary                 HR  Healthcare
# 1     EMP0002   40      Female     Data Scientist          IT
# 2     EMP0003   59  Non-binary  Software Engineer   Education
# 3     EMP0004   27        Male  Software Engineer     Finance
# 4     EMP0005   49        Male              Sales  Consulting
#
#    Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                   13        Hybrid                     47
# 1                    3        Remote                     52
# 2                   22        Hybrid                     46
# 3                   20        Onsite                     32
# 4                   32        Onsite                     35
#
#    Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                           7                         2       Medium
# 1                           4                         1       Medium
# ...

# %%
#Print out the basic information about the dataframe to identify whether the number of responses is equal or if some responses are missing. Also, to review the data types.
df.info()

# %%
#Convert string values to integers to be able to calculate.
df['Stress_Level'].replace({'Low': 1, 'Medium': 2, 'High': 3}, inplace=True)
df
# Out:
# C:\Users\melit\AppData\Local\Temp\ipykernel_144084\2539612708.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Stress_Level'].replace({'Low': 1, 'Medium': 2, 'High': 3}, inplace=True)
# ...

# %%
#Convert string values to integers to be able to calculate.
df['Productivity_Change'].replace({'Decrease': 1, 'No Change': 2, 'Increase': 3}, inplace=True)
df

# %%
#Convert string values to integers to be able to calculate.
df['Satisfaction_with_Remote_Work'].replace({'Unsatisfied': 1, 'Neutral': 2, 'Satisfied': 3}, inplace=True)
df

# %%
#Convert string values to integers to be able to calculate.
df['Physical_Activity'].replace({'Daily': 3, 'Weekly': 2}, inplace=True)
df

# %%
#Enter the word "None" for "NaN" values.
df['Physical_Activity'].fillna('None', inplace=True)
df

# %%
#Assign an integer value to the string value in order to calculate.
df['Physical_Activity'].replace({'None': 1}, inplace=True)
df

# %%
#Convert values with a decimal to a whole number in the Physical Activity column.
df['Physical_Activity'] = df["Physical_Activity"].astype(int)
df

# %%
#Convert string values to integers to be able to calculate.
df['Sleep_Quality'].replace({'Good': 1, 'Average': 2, 'Poor': 3}, inplace=True)
df

# %%
#Enter the word "Not Reported" for "NaN" values.
df['Mental_Health_Condition'].fillna('Not Reported', inplace=True)
df

# %%
#Remove Employee_ID column, as there is already an index.
df = df.drop(['Employee_ID'], axis=1)

#Print out first 5 rows to make sure Employee_ID column has been removed from the dataframe.
df.head()

# %%
#
df.groupby(['Industry', 'Job_Role'])['Hours_Worked_Per_Week'].mean()

# %%
df.groupby(['Job_Role'])['Age'].mean()

# %%
df.groupby(['Job_Role'])['Work_Location'].value_counts()

# %%
df.groupby(['Region'])['Stress_Level'].mean()

# %%
df.groupby(['Region', 'Work_Location'])['Stress_Level'].mean()

# %%
hybrid = [2.003448, 1.917910, 2.074733, 2.003831, 1.982394, 2.083019]
onsite = [2.015038, 2.015038, 1.963768, 1.972222, 1.993174, 2.007018]
remote = [2.075658, 2.000000, 2.091873, 1.984848, 1.993103, 2.000000]
index = ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']

df = pd.DataFrame({'Hybrid': hybrid, 'Onsite': onsite, 'Remote': remote}, index=index)

ax = df.plot.bar(rot=0)

ax.set_xlim(-1,6)
ax.set_ylim(0, 5)

# %%
df.groupby(['Access_to_Mental_Health_Resources', 'Work_Location'])['Stress_Level'].mean()
# Out:
# Access_to_Mental_Health_Resources  Work_Location
# No                                 Hybrid           1.984468
#                                    Onsite           1.953659
#                                    Remote           1.997768
# Yes                                Hybrid           2.038177
#                                    Onsite           2.022032
#                                    Remote           2.055012
# Name: Stress_Level, dtype: float64

# %%
hybrid = [1.984468, 2.038177]
onsite = [1.953659, 2.022032]
remote = [1.997768, 2.055012]
index = ['No', 'Yes']

df = pd.DataFrame({'Hybrid': hybrid, 'Onsite': onsite, 'Remote': remote}, index = index)

ax = df.plot.bar(rot=0)

ax.set_xlim(-1, 2)
ax.set_ylim(0, 5)
# Out:
# (0.0, 5.0)
